# %%
from glob import glob
from nibabel import load as ld
from tqdm import tqdm

data = "/home/tbarba/projects/MultiModalBrainSurvival/data/MR/UKBIOBANK/processed"

# %%
# files = glob(data + "/*/norm*crop.nii.gz")
# for f in tqdm(files):
#     print(f)
#     ld(f)

# %%
from src.autoencoder.datasets import BrainImages
from src.autoencoder import datasets
from torch.utils.data import DataLoader

import torch

# %%
import yaml
import argparse
import os
from os.path import join, exists
import pandas as pd
import matplotlib.pyplot as plt
import configparser
import torch
from torchvision.utils import save_image, make_grid
import numpy as np
from tqdm import tqdm
from torchvision import transforms as transforms
from src.autoencoder.datasets import BrainImages, SingleMod
from torch.utils.data import DataLoader
from torch.utils.data.dataset import random_split

# %%
trainLoader = torch.load("/home/tbarba/projects/MultiModalBrainSurvival/outputs/norm/fused_allmods/exports/fullLoader.pth")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/tbarba/projects/MultiModalBrainSurvival/debug.ipynb Cell 5 in 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcarina/home/tbarba/projects/MultiModalBrainSurvival/debug.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> trainLoader = torch.load("/home/tbarba/projects/MultiModalBrainSurvival/outputs/norm/fused_allmods/exports/fullLoader.pth")
#
# File /share/pi/ogevaert/thomas/miniconda/envs/multimodal/lib/python3.9/site-packages/torch/serialization.py:809, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     807             except RuntimeError as e:
#     808                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 809         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     810 if weights_only:
#     811     try:
#
# ...

# %%
for idx, (img, case) in enumerate(tqdm(trainLoader)):
    break
# Out:
#   0%|          | 0/19955 [00:01<?, ?it/s]

# %%
img.shape
# Out:
# torch.Size([1, 2, 160, 218, 182])

# %%
a = img[0,1,100,:,:]
plt.imshow(a)

# %%
b1 = ld("/home/tbarba/projects/MultiModalBrainSurvival/data/MR/UKBIOBANK/processed/1000805/normT1_crop.nii.gz")
b2 = ld("/home/tbarba/projects/MultiModalBrainSurvival/data/MR/UKBIOBANK/processed/1000805/normT2_crop.nii.gz")

# %%
import torchio as tio
rescale = tio.RescaleIntensity(out_min_max=(0,1))
c = [b1, b2]
c = [rescale(i).get_fdata() for i in c]
c = np.array(c, dtype=np.float32).transpose((0, 3, 2, 1))
c = np.flip(c, 2)
plt.imshow(c[0,80,:,:])

# %%
c[0,80,:,:]
# Out:
# array([[0.00068608, 0.00068608, 0.00068608, ..., 0.00068608, 0.00068608,
#         0.00068608],
#        [0.00068608, 0.00068608, 0.00068608, ..., 0.00068608, 0.00068608,
#         0.00068608],
#        [0.00068608, 0.00068608, 0.00068608, ..., 0.00068608, 0.00068608,
#         0.00068608],
#        ...,
#        [0.00068608, 0.00068608, 0.00068608, ..., 0.00068608, 0.00068608,
#         0.00068608],
#        [0.00068608, 0.00068608, 0.00068608, ..., 0.00068608, 0.00068608,
#         0.00068608],
#        [0.00068608, 0.00068608, 0.00068608, ..., 0.00068608, 0.00068608,
#         0.00068608]], dtype=float32)

# %%
case = 3680093
data = f"/home/tbarba/projects/MultiModalBrainSurvival/data/MR/UKBIOBANK/processed/{case}/normT2.nii.gz"

pa(data)

# %%
pa("/home/tbarba/projects/MultiModalBrainSurvival/data/MR/UKBIOBANK/processed/3680093/normT2.nii.gz")

# %%
pa("/home/tbarba/projects/MultiModalBrainSurvival/data/MR/UKBIOBANK/processed/3678919/normT2_crop.nii.gz")
